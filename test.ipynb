# %%
import pandas as pd
data = pd.read_csv('project_model_ui\wine.csv')
data.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\warisha khan\AppData\Local\Temp\ipykernel_12500\3816545475.py:2: SyntaxWarning: invalid escape sequence '\w'
#   data = pd.read_csv('project_model_ui\wine.csv')
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
y=data['quality']
x=data.drop(['quality'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.25, random_state=42 )
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
#model.predict(x_train[1:4])
from sklearn.metrics import accuracy_score
y_pred=model.predict(x_test)
accuracy= accuracy_score(y_test,y_pred)
print("Accuracy of model is: ", accuracy)
# Out:
# Accuracy of model is:  0.5475
# c:\Users\warisha khan\Desktop\training\tf_env\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import pandas as pd
data = pd.read_csv('project_model_ui\wine.csv')

y=data['quality']
x=data.drop(['quality'],axis=1)


from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(random_state=42)
model.fit(x_train,y_train)
from sklearn.metrics import accuracy_score
y_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy of the model is=", accuracy)
# Out:
# Accuracy of the model is= 0.5825
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\warisha khan\AppData\Local\Temp\ipykernel_12500\498508785.py:2: SyntaxWarning: invalid escape sequence '\w'
#   data = pd.read_csv('project_model_ui\wine.csv')

# %%
import pandas as pd
data = pd.read_csv('project_model_ui\wine.csv')

y=data['quality']
x=data.drop(['quality'],axis=1)


from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(random_state=42)
model.fit(x_train,y_train)
from sklearn.metrics import accuracy_score
y_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy of the model is=", accuracy)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\warisha khan\AppData\Local\Temp\ipykernel_12500\2130633248.py:2: SyntaxWarning: invalid escape sequence '\w'
#   data = pd.read_csv('project_model_ui\wine.csv')
# Accuracy of the model is= 0.67

# %%
li=[110,2,5,20,40,50,100,150]
cc1=7
cc2=45
clust1=[]
clust2=[]
for i in li:
    if abs(i-cc1)<abs(i-cc2):
        clust1.append(i)
    else:
        clust2.append(i)

print("Cluster 1:",clust1)
print("Cluster 2:",clust2)
# Out:
# Cluster 1: [2, 5, 20]
# Cluster 2: [110, 40, 50, 100, 150]

# %%
cc1=sum(clust1)/len(clust1)
cc2=sum(clust2)/len(clust2)
clust1=[]
clust2=[]
for i in li:
    if abs(i-cc1)<abs(i-cc2):
        clust1.append(i)
    else:
        clust2.append(i)

print("Cluster 1:",clust1)
print("Cluster 2:",clust2)
# Out:
# Cluster 1: [2, 5, 20, 40]
# Cluster 2: [110, 50, 100, 150]

# %%
cc1=sum(clust1)/len(clust1)
cc2=sum(clust2)/len(clust2)
clust1=[]
clust2=[]
for i in li:
    if abs(i-cc1)<abs(i-cc2):
        clust1.append(i)
    else:
        clust2.append(i)

print("Cluster 1:",clust1)
print("Cluster 2:",clust2)
# Out:
# Cluster 1: [2, 5, 20, 40, 50]
# Cluster 2: [110, 100, 150]

# %%
cc1=sum(clust1)/len(clust1)
cc2=sum(clust2)/len(clust2)
clust1=[]
clust2=[]
for i in li:
    if abs(i-cc1)<abs(i-cc2):
        clust1.append(i)
    else:
        clust2.append(i)

print("Cluster 1:",clust1)
print("Cluster 2:",clust2)
# Out:
# Cluster 1: [2, 5, 20, 40, 50]
# Cluster 2: [110, 100, 150]

# %%
li=[110,2,5,20,40,50,100,150]
import numpy as np
from sklearn.cluster import KMeans
kmeans=KMeans()
model=kmeans.fit(np.array(li).reshape(-1,1))

# %%
import pandas as pd
data = pd.read_csv('project_model_ui\wine.csv')
y = data['quality']
x = data.drop(['quality'], axis=1)
#data.head()
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.25, random_state=42 )

from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(hidden_layer_sizes=(6,5),
                    random_state=5,
                    verbose=True,
                    learning_rate_init= 0.01)
clf.fit(x_train,y_train)
# Out:
# Iteration 1, loss = 20.11451744
# Iteration 2, loss = 10.84787675
# Iteration 3, loss = 6.55556444
# Iteration 4, loss = 4.62833060
# Iteration 5, loss = 2.86952062
# Iteration 6, loss = 2.16788956
# Iteration 7, loss = 1.79510285
# Iteration 8, loss = 1.50643080
# Iteration 9, loss = 1.39582257
# Iteration 10, loss = 1.33842867
# Iteration 11, loss = 1.29943917
# Iteration 12, loss = 1.28106199
# Iteration 13, loss = 1.25934940
# Iteration 14, loss = 1.24133964
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\warisha khan\AppData\Local\Temp\ipykernel_12500\385595386.py:2: SyntaxWarning: invalid escape sequence '\w'
#   data = pd.read_csv('project_model_ui\wine.csv')
# Iteration 15, loss = 1.21429778
# Iteration 16, loss = 1.20070078
# Iteration 17, loss = 1.19438063
# Iteration 18, loss = 1.18801833
# Iteration 19, loss = 1.18131330
# Iteration 20, loss = 1.17645959
# Iteration 21, loss = 1.17349410
# Iteration 22, loss = 1.16928084
# Iteration 23, loss = 1.16661900
# Iteration 24, loss = 1.16350493
# Iteration 25, loss = 1.16099609
# Iteration 26, loss = 1.16113508
# Iteration 27, loss = 1.15983841
# Iteration 28, loss = 1.15628321
# Iteration 29, loss = 1.15961959
# Iteration 30, loss = 1.16212186
# Iteration 31, loss = 1.16084591
# Iteration 32, loss = 1.15293470
# Iteration 33, loss = 1.15206461
# Iteration 34, loss = 1.15294806
# Iteration 35, loss = 1.15280676
# Iteration 36, loss = 1.15194013
# Iteration 37, loss = 1.15119633
# Iteration 38, loss = 1.14987819
# Iteration 39, loss = 1.15092658
# Iteration 40, loss = 1.15050208
# Iteration 41, loss = 1.15034231
# Iteration 42, loss = 1.14757689
# Iteration 43, loss = 1.14900924
# Iteration 44, loss = 1.14798820
# Iteration 45, loss = 1.14627847
# Iteration 46, loss = 1.14576680
# Iteration 47, loss = 1.14601396
# Iteration 48, loss = 1.14558137
# Iteration 136, loss = 1.09574021
# Iteration 137, loss = 1.09388634
# Iteration 138, loss = 1.09257037
# Iteration 139, loss = 1.09085895
# Iteration 140, loss = 1.08760340
# Iteration 141, loss = 1.08587073
# Iteration 142, loss = 1.08801970
# Iteration 143, loss = 1.08258031
# Iteration 144, loss = 1.08150916
# Iteration 145, loss = 1.08315226
# Iteration 146, loss = 1.08211100
# Iteration 147, loss = 1.07909460
# Iteration 148, loss = 1.08026291
# Iteration 149, loss = 1.07662508
# Iteration 150, loss = 1.07296057
# Iteration 151, loss = 1.07724918
# Iteration 152, loss = 1.07934455
# Iteration 153, loss = 1.06623300
# Iteration 154, loss = 1.06487284
# Iteration 155, loss = 1.06127378
# Iteration 156, loss = 1.05955289
# Iteration 157, loss = 1.05763273
# Iteration 158, loss = 1.05438460
# Iteration 159, loss = 1.05311533
# Iteration 160, loss = 1.05099224
# Iteration 161, loss = 1.04817691
# Iteration 162, loss = 1.05227432
# Iteration 163, loss = 1.04300912
# Iteration 164, loss = 1.03785505
# Iteration 165, loss = 1.03480039
# Iteration 166, loss = 1.03324731
# Iteration 167, loss = 1.03049313
# Iteration 168, loss = 1.03105245
# Iteration 169, loss = 1.02674895
# Iteration 170, loss = 1.02825711
# Iteration 171, loss = 1.02065261
# Iteration 172, loss = 1.02448759
# Iteration 173, loss = 1.02279864
# Iteration 174, loss = 1.01779651
# Iteration 175, loss = 1.00905822
# Iteration 176, loss = 1.00803013
# Iteration 177, loss = 1.00482103
# Iteration 178, loss = 1.00446962
# Iteration 179, loss = 1.00073463
# Iteration 180, loss = 0.99353495
# Iteration 181, loss = 1.00023683
# Iteration 182, loss = 1.00009074
# Iteration 183, loss = 0.98737372
# Iteration 184, loss = 0.98719295
# Iteration 185, loss = 0.98273959
# Iteration 186, loss = 0.98950083
# Iteration 187, loss = 0.98297021
# Iteration 188, loss = 0.97818115
# Iteration 189, loss = 0.97842878
# Iteration 190, loss = 0.98124960
# Iteration 191, loss = 0.97345923
# Iteration 192, loss = 0.97704058
# Iteration 193, loss = 0.97077011
# Iteration 194, loss = 0.97573120
# Iteration 195, loss = 0.96763044
# Iteration 196, loss = 0.97749613
# Iteration 197, loss = 0.98556826
# Iteration 198, loss = 0.98424960
# Iteration 199, loss = 0.97688525
# Iteration 200, loss = 0.97824722
# c:\Users\warisha khan\Desktop\training\tf_env\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(6, 5), learning_rate_init=0.01,
#               random_state=5, verbose=True)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('project_model_ui\wine.csv')

y = data["quality"]
x = data.drop(["quality"], axis=1)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\warisha khan\AppData\Local\Temp\ipykernel_12500\797177260.py:1: SyntaxWarning: invalid escape sequence '\w'
#   data = pd.read_csv('project_model_ui\wine.csv')

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.25,
    random_state=42
)

# %%
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(
    hidden_layer_sizes=(6,5),
    random_state=5,
    verbose=True,
    learning_rate_init=0.01
)

clf.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 20.11451744
# Iteration 2, loss = 10.84787675
# Iteration 3, loss = 6.55556444
# Iteration 4, loss = 4.62833060
# Iteration 5, loss = 2.86952062
# Iteration 6, loss = 2.16788956
# Iteration 7, loss = 1.79510285
# Iteration 8, loss = 1.50643080
# Iteration 9, loss = 1.39582257
# Iteration 10, loss = 1.33842867
# Iteration 11, loss = 1.29943917
# Iteration 12, loss = 1.28106199
# Iteration 13, loss = 1.25934940
# Iteration 14, loss = 1.24133964
# Iteration 15, loss = 1.21429778
# Iteration 16, loss = 1.20070078
# Iteration 17, loss = 1.19438063
# Iteration 18, loss = 1.18801833
# Iteration 19, loss = 1.18131330
# Iteration 20, loss = 1.17645959
# Iteration 21, loss = 1.17349410
# Iteration 22, loss = 1.16928084
# Iteration 23, loss = 1.16661900
# Iteration 24, loss = 1.16350493
# Iteration 25, loss = 1.16099609
# Iteration 26, loss = 1.16113508
# Iteration 27, loss = 1.15983841
# Iteration 28, loss = 1.15628321
# Iteration 29, loss = 1.15961959
# Iteration 30, loss = 1.16212186
# Iteration 31, loss = 1.16084591
# Iteration 32, loss = 1.15293470
# Iteration 33, loss = 1.15206461
# Iteration 34, loss = 1.15294806
# Iteration 35, loss = 1.15280676
# Iteration 36, loss = 1.15194013
# Iteration 37, loss = 1.15119633
# Iteration 38, loss = 1.14987819
# Iteration 39, loss = 1.15092658
# Iteration 40, loss = 1.15050208
# Iteration 41, loss = 1.15034231
# Iteration 42, loss = 1.14757689
# Iteration 43, loss = 1.14900924
# Iteration 44, loss = 1.14798820
# Iteration 45, loss = 1.14627847
# Iteration 46, loss = 1.14576680
# Iteration 47, loss = 1.14601396
# Iteration 48, loss = 1.14558137
# Iteration 49, loss = 1.14592414
# Iteration 50, loss = 1.14505554
# Iteration 51, loss = 1.14625681
# Iteration 52, loss = 1.14440277
# Iteration 53, loss = 1.14402922
# Iteration 54, loss = 1.14534875
# Iteration 55, loss = 1.14605099
# Iteration 56, loss = 1.14409791
# Iteration 57, loss = 1.14251380
# Iteration 58, loss = 1.14302310
# Iteration 59, loss = 1.14161456
# Iteration 60, loss = 1.14202694
# Iteration 61, loss = 1.14052123
# Iteration 62, loss = 1.14080888
# Iteration 63, loss = 1.14069916
# Iteration 64, loss = 1.14184895
# Iteration 65, loss = 1.14213704
# Iteration 66, loss = 1.14147484
# Iteration 67, loss = 1.14237645
# Iteration 68, loss = 1.14031323
# Iteration 69, loss = 1.13931112
# Iteration 70, loss = 1.14232011
# Iteration 71, loss = 1.13877588
# Iteration 72, loss = 1.13808194
# Iteration 73, loss = 1.13911952
# Iteration 74, loss = 1.13767894
# Iteration 75, loss = 1.13781333
# Iteration 76, loss = 1.13757823
# Iteration 77, loss = 1.13737625
# Iteration 78, loss = 1.13786548
# Iteration 79, loss = 1.13783394
# Iteration 80, loss = 1.13609206
# Iteration 81, loss = 1.13538119
# Iteration 82, loss = 1.13552689
# Iteration 83, loss = 1.13752047
# Iteration 84, loss = 1.13468495
# Iteration 85, loss = 1.13541240
# Iteration 86, loss = 1.13526720
# Iteration 87, loss = 1.13354783
# Iteration 88, loss = 1.13340645
# Iteration 176, loss = 1.00803013
# Iteration 177, loss = 1.00482103
# Iteration 178, loss = 1.00446962
# Iteration 179, loss = 1.00073463
# Iteration 180, loss = 0.99353495
# Iteration 181, loss = 1.00023683
# Iteration 182, loss = 1.00009074
# Iteration 183, loss = 0.98737372
# Iteration 184, loss = 0.98719295
# Iteration 185, loss = 0.98273959
# Iteration 186, loss = 0.98950083
# Iteration 187, loss = 0.98297021
# Iteration 188, loss = 0.97818115
# Iteration 189, loss = 0.97842878
# Iteration 190, loss = 0.98124960
# Iteration 191, loss = 0.97345923
# Iteration 192, loss = 0.97704058
# Iteration 193, loss = 0.97077011
# Iteration 194, loss = 0.97573120
# Iteration 195, loss = 0.96763044
# Iteration 196, loss = 0.97749613
# Iteration 197, loss = 0.98556826
# Iteration 198, loss = 0.98424960
# Iteration 199, loss = 0.97688525
# Iteration 200, loss = 0.97824722
# c:\Users\warisha khan\Desktop\training\tf_env\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(6, 5), learning_rate_init=0.01,
#               random_state=5, verbose=True)

# %%
print(clf.score(x_train, y_train))
print(clf.score(x_test, y_test))
# Out:
# 0.5788156797331109
# 0.525

# %%
model = MLPClassifier(
    hidden_layer_sizes=(64,32),
    activation="tanh",
    max_iter=500
)

model.fit(x_train, y_train)

print(model.score(x_train, y_train))
print(model.score(x_test, y_test))
# Out:
# 0.6722268557130943
# 0.5975

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.21.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
y_train = y_train - 3
y_test = y_test - 3

print(np.unique(y_train))
# Out:
# [0 1 2 3 4 5]

# %%
model = Sequential()

model.add(Dense(
    64,
    input_dim=x_train.shape[1],
    activation="relu"
))

model.add(Dense(
    6,
    activation="softmax"
))
# Out:
# c:\Users\warisha khan\Desktop\training\tf_env\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.3970 - loss: 2.8813 - val_accuracy: 0.4875 - val_loss: 1.3935
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4862 - loss: 1.2830 - val_accuracy: 0.5075 - val_loss: 1.2380
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4879 - loss: 1.2547 - val_accuracy: 0.4125 - val_loss: 1.3040
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4879 - loss: 1.1946 - val_accuracy: 0.4550 - val_loss: 1.2018
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5038 - loss: 1.1483 - val_accuracy: 0.4300 - val_loss: 1.1629
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4996 - loss: 1.1756 - val_accuracy: 0.4575 - val_loss: 1.2126
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5480 - loss: 1.0774 - val_accuracy: 0.5200 - val_loss: 1.0617
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5563 - loss: 1.0570 - val_accuracy: 0.4325 - val_loss: 1.2861
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5071 - loss: 1.1680 - val_accuracy: 0.5175 - val_loss: 1.0992
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5238 - loss: 1.1014 - val_accuracy: 0.5000 - val_loss: 1.0981
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5505 - loss: 1.0583 - val_accuracy: 0.4975 - val_loss: 1.0762
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.
# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(64, input_dim=10, activation='relu'))
model.add(Dense(6, activation='softmax'))

model.summary()
# Out:
# c:\Users\warisha khan\Desktop\training\tf_env\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_39 (Dense)                │ (None, 64)             │           704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,094 (4.27 KB)
#  Trainable params: 1,094 (4.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(x_train)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 582            11.7             0.490         0.49             2.2      0.083
# 626             8.8             0.600         0.29             2.2      0.098
# 1030            7.1             0.590         0.00             2.1      0.091
# 620             8.3             0.540         0.24             3.4      0.076
# 490             9.3             0.775         0.27             2.8      0.078
# ...             ...               ...          ...             ...        ...
# 1130            9.1             0.600         0.00             1.9      0.058
# 1294            8.2             0.635         0.10             2.1      0.073
# 860             7.2             0.620         0.06             2.7      0.077
# 1459            7.9             0.200         0.35             1.7      0.054
# 1126            5.8             0.290         0.26             1.7      0.063
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 582                   5.0                  15.0  1.00000  3.19       0.43
# 626                   5.0                  15.0  0.99880  3.36       0.49
# 1030                  9.0                  14.0  0.99488  3.42       0.55
# 620                  16.0                 112.0  0.99760  3.27       0.61
# 490                  24.0                  56.0  0.99840  3.31       0.67
# ...                   ...                   ...      ...   ...        ...
# 1130                  5.0                  10.0  0.99770  3.18       0.63
# 1294                 25.0                  60.0  0.99638  3.29       0.75
# 860                  15.0                  85.0  0.99746  3.51       0.54
# 1459                  7.0                  15.0  0.99458  3.32       0.80
# 1126                  3.0                  11.0  0.99150  3.39       0.54
#
#       alcohol
# 582       9.2
# 626       9.1
# 1030     11.5
# 620       9.4
# 490      10.6
# ...       ...
# 1130     10.4
# 1294     10.9
# 860       9.5
# 1459     11.9
# 1126     13.5
#
# [1199 rows x 11 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(64, input_dim=x_train.shape[1], activation='relu'))
model.add(Dense(6, activation='softmax'))
from tensorflow.keras.optimizers import Adam
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\warisha khan\Desktop\training\tf_env\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_22 (Dense)                │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,158 (4.52 KB)
#  Trainable params: 1,158 (4.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.predict(x_test))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# [[6.7595596e-05 6.0483575e-07 7.5697702e-01 2.0600241e-03 2.4089395e-01
#   9.1857430e-07]
#  [1.0153806e-09 4.2035242e-13 7.9154325e-01 1.3649555e-05 2.0844315e-01
#   9.8788809e-15]
#  [8.6791941e-04 5.0854096e-06 7.3046643e-01 1.6671523e-03 2.6697651e-01
#   1.6915210e-05]
#  ...
#  [5.3327862e-04 1.6095099e-05 4.5881855e-01 6.7551611e-03 5.3385901e-01
#   1.7911425e-05]
#  [2.5439423e-02 3.0832383e-04 6.6790611e-01 1.3468044e-02 2.8454125e-01
#   8.3368914e-03]
#  [2.6681323e-02 9.1441689e-05 8.3499235e-01 5.3100171e-03 1.2402442e-01
#   8.9003360e-03]]

# %%
# Out:
# [0 1 2 3 4 5]
