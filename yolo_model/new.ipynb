# %%
import ultralytics as ut

# %%
import cv2
from ultralytics import YOLO
model = YOLO('yolo11n.pt')
predict_class=[0,14]
img= 'lio2.jpg'
pred = model(img ,classes=predict_class ,conf=0.4)
pred_img=pred[0].plot()
cv2.imwrite("ans.jpg",pred_img)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 3.5MB/s 1.5s.5s<0.0s2.1s0s
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       2 from ultralytics import YOLO
#       3 model = YOLO('yolo11n.pt')
#       4 predict_class=[0,14]
#       5 img= 'lio2.jpg'
# ----> 6 pred = model(img ,classes=predict_class ,conf=0.4)
#       7 pred_img=pred[0].plot()
#       8 cv2.imwrite("ans.jpg",pred_img)
#
# File c:\Users\warisha khan\Desktop\training\opencv_env\Lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    175         ...     print(f"Detected {len(r)} objects in image")
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File c:\Users\warisha khan\Desktop\training\opencv_env\Lib\site-packages\ultralytics\engine\model.py:541, in Model.predict(self, source, stream, predictor, **kwargs)
#     539 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     540     self.predictor.set_prompts(prompts)
# --> 541 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\warisha khan\Desktop\training\opencv_env\Lib\site-packages\ultralytics\engine\predictor.py:229, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     227     return self.stream_inference(source, model, *args, **kwargs)
#     228 else:
# --> 229     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\warisha khan\Desktop\training\opencv_env\Lib\site-packages\torch\utils\_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File c:\Users\warisha khan\Desktop\training\opencv_env\Lib\site-packages\ultralytics\engine\predictor.py:303, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     299     self.setup_model(model)
#     301 with self._lock:  # for thread-safe inference
#     302     # Setup source every time predict is called
# --> 303     self.setup_source(source if source is not None else self.args.source)
#     305     # Check if save_dir/ label file exists
#     306     if self.args.save or self.args.save_txt:
#
# File c:\Users\warisha khan\Desktop\training\opencv_env\Lib\site-packages\ultralytics\engine\predictor.py:260, in BasePredictor.setup_source(self, source, stride)
#     252 """Set up source and inference mode.
#     253
#     254 Args:
#    (...)    257     stride (int, optional): Model stride for image size checking.
#     258 """
#     259 self.imgsz = check_imgsz(self.args.imgsz, stride=stride or self.model.stride, min_dim=2)  # check image size
# --> 260 self.dataset = load_inference_source(
#     261     source=source,
#     262     batch=self.args.batch,
#     263     vid_stride=self.args.vid_stride,
#     264     buffer=self.args.stream_buffer,
#     265     channels=getattr(self.model, "channels", 3),
#     266 )
#     267 self.source_type = self.dataset.source_type
#     268 if (
#     269     self.source_type.stream
#     270     or self.source_type.screenshot
#     271     or len(self.dataset) > 1000  # many images
#     272     or any(getattr(self.dataset, "video_flag", [False]))
#     273 ):  # long sequence
#
# File c:\Users\warisha khan\Desktop\training\opencv_env\Lib\site-packages\ultralytics\data\build.py:467, in load_inference_source(source, batch, vid_stride, buffer, channels)
#     465     dataset = LoadPilAndNumpy(source, channels=channels)
#     466 else:
# --> 467     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#     469 # Attach source types to the dataset
#     470 setattr(dataset, "source_type", source_type)
#
# File c:\Users\warisha khan\Desktop\training\opencv_env\Lib\site-packages\ultralytics\data\loaders.py:374, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride, channels)
#     372         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     373     else:
# --> 374         raise FileNotFoundError(f"{p} does not exist")
#     376 # Define files as images or videos
#     377 images, videos = [], []
#
# FileNotFoundError: lio2.jpg does not exist
